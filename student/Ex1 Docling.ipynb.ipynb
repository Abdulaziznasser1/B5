# %%
# !pip install docling
from docling.document_converter import DocumentConverter
from pathlib import Path

# Change this to a local path or another URL if desired.
# Note: using the default URL requires network access; if offline, provide a
# local file path (e.g., Path("/path/to/file.pdf")).
# Please upload 'Slides_Simple.docx' to the Colab environment (e.g., to /content/).
source = Path("Slides_Simple.docx") # Assuming the file is now uploaded to the Colab environment.

converter = DocumentConverter()
result = converter.convert(source);

# Print Markdown to stdout.
print(result.document.export_to_markdown())
# Out:
# ...
# **Employee Attrition Predictor**
#
# ML Project  |  8-Minute Presentation
#
# **SLIDE 1  Title &amp; Overview**
#
# - **What:** Predict if an employee will leave the company (Yes or No).
# - **Domain:** HR / People Analytics
# - **Goal:** Help HR teams catch at-risk employees early — before they quit.
#
# → Replacing one employee costs 6–9 months of their salary.
#
# **SLIDE 2  The Status Quo**
#
# - **Current approach:** HR managers guess based on gut feeling and annual surveys.
# - **Problem 1:** It's too late — they only find out after the employee decides to leave.
# - **Problem 2:** It doesn't scale — impossible to track 35 signals across 1,000+ employees manually.
# - **Problem 3:** It's inaccurate — catches only ~30% of attrition cases.
#
# **SLIDE 3  The Case for Machine Learning**
#
# - **ML Task:** Binary Classification — predict Attrition = Yes or No.
#
# | **Factor**   | **Details**                                                                       |
# ...
