# %% [markdown]
# # Fictional Army - Filtering and Sorting

# %% [markdown]
# ### Introduction:
#
# This exercise was inspired by this [page](http://chrisalbon.com/python/)
#
# Special thanks to: https://github.com/chrisalbon for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. This is the data given as a dictionary

# %%
data = {
    'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons'],
    'company': ['1st', '2nd', '3rd', '4th', '1st', '2nd', '3rd', '4th'],
    'deaths': [51, 34, 65, 25, 48, 52, 66, 32],
    'battles': [5, 3, 6, 3, 7, 8, 5, 6],
    'size': [1045, 834, 913, 721, 982, 1023, 876, 765],
    'veterans': [1, 4, 5, 2, 3, 4, 3, 2],
    'readiness': ['yes', 'no', 'yes', 'no', 'yes', 'no', 'no', 'yes'],
    'deserters': [5, 2, 1, 3, 2, 3, 4, 1],  # ← THIS WAS MISSING
    'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington']
}

# %% [markdown]
# ### Step 3. Create a dataframe and assign it to a variable called army.
#
# #### Don't forget to include the columns names in the order presented in the dictionary ('regiment', 'company', 'deaths'...) so that the column index order is consistent with the solutions. If omitted, pandas will order the columns alphabetically.

# %%
army = pd.DataFrame(data, columns=['regiment', 'company', 'deaths', 'battles', 'size', 'veterans', 'readiness', 'deserters', 'origin'])

# %%
army = pd.DataFrame(data, columns=['regiment', 'company', 'deaths', 'battles', 'size', 'veterans', 'readiness', 'origin'])

# %% [markdown]
# ### Step 4. Set the 'origin' colum as the index of the dataframe

# %%
army.set_index('origin', inplace=True)

# %% [markdown]
# ### Step 5. Print only the column veterans

# %%
army['veterans']
# Out:
# origin
# Arizona       1
# California    4
# Texas         5
# Florida       2
# Maine         3
# Iowa          4
# Alaska        3
# Washington    2
# Name: veterans, dtype: int64

# %% [markdown]
# ### Step 6. Print the columns 'veterans' and 'deaths'

# %%
army[['veterans', 'deaths']]
# Out:
#             veterans  deaths
# origin
# Arizona            1      51
# California         4      34
# Texas              5      65
# Florida            2      25
# Maine              3      48
# Iowa               4      52
# Alaska             3      66
# Washington         2      32

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
army.columns
# Out:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'readiness'],
#       dtype='str')

# %% [markdown]
# ### Step 8. Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska

# %%
army.columns
# Out:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'readiness'],
#       dtype='str')

# %% [markdown]
# ### Step 9. Select the rows 3 to 7 and the columns 3 to 6

# %%
army.iloc[3:8, 3:7]
# Out:
#             battles  size  veterans readiness
# origin
# Florida           3   721         2        no
# Maine             7   982         3       yes
# Iowa              8  1023         4        no
# Alaska            5   876         3        no
# Washington        6   765         2       yes

# %% [markdown]
# ### Step 10. Select every row after the fourth row and all columns

# %%
army.iloc[4:]
# Out:
#             regiment company  deaths  battles  size  veterans readiness  \
# origin
# Maine       Dragoons     1st      48        7   982         3       yes
# Iowa        Dragoons     2nd      52        8  1023         4        no
# Alaska      Dragoons     3rd      66        5   876         3        no
# Washington  Dragoons     4th      32        6   765         2       yes
#
#             deserters
# origin
# Maine               2
# Iowa                3
# Alaska              4
# Washington          1

# %% [markdown]
# Select## Step 11.  every row up to the 4th row and all columns

# %%
army.iloc[:4]
# Out:
#               regiment company  deaths  battles  size  veterans readiness  \
# origin
# Arizona     Nighthawks     1st      51        5  1045         1       yes
# California  Nighthawks     2nd      34        3   834         4        no
# Texas       Nighthawks     3rd      65        6   913         5       yes
# Florida     Nighthawks     4th      25        3   721         2        no
#
#             deserters
# origin
# Arizona             5
# California          2
# Texas               1
# Florida             3

# %% [markdown]
# ### Step 12. Select the 3rd column up to the 7th column

# %%
army.iloc[:, 2:7]
# Out:
#             deaths  battles  size  veterans readiness
# origin
# Arizona         51        5  1045         1       yes
# California      34        3   834         4        no
# Texas           65        6   913         5       yes
# Florida         25        3   721         2        no
# Maine           48        7   982         3       yes
# Iowa            52        8  1023         4        no
# Alaska          66        5   876         3        no
# Washington      32        6   765         2       yes

# %% [markdown]
# ### Step 13. Select rows where df.deaths is greater than 50

# %%
army[army['deaths'] > 50]
# Out:
#            regiment company  deaths  battles  size  veterans readiness  \
# origin
# Arizona  Nighthawks     1st      51        5  1045         1       yes
# Texas    Nighthawks     3rd      65        6   913         5       yes
# Iowa       Dragoons     2nd      52        8  1023         4        no
# Alaska     Dragoons     3rd      66        5   876         3        no
#
#          deserters
# origin
# Arizona          5
# Texas            1
# Iowa             3
# Alaska           4

# %% [markdown]
# ### Step 14. Select rows where df.deaths is greater than 500 or less than 50

# %%
army[(army['deaths'] > 500) | (army['deaths'] < 50)]
# Out:
#               regiment company  deaths  battles  size  veterans readiness  \
# origin
# California  Nighthawks     2nd      34        3   834         4        no
# Florida     Nighthawks     4th      25        3   721         2        no
# Maine         Dragoons     1st      48        7   982         3       yes
# Washington    Dragoons     4th      32        6   765         2       yes
#
#             deserters
# origin
# California          2
# Florida             3
# Maine               2
# Washington          1

# %% [markdown]
# ### Step 15. Select all the regiments not named "Dragoons"

# %% [markdown]
# ### Step 16. Select the rows called Texas and Arizona

# %% [markdown]
# ### Step 17. Select the third cell in the row named Arizona

# %% [markdown]
# ### Step 18. Select the third cell down in the column named deaths

# %%
army.iloc[2, 2]
